# %%
import mplfinance as mpf
import pandas as pd

# %%
#* Get data from Stooq 2022 daily chart
data = pd.read_csv("https://stooq.com/q/d/l/?s=^spx&d1=20220101&d2=20221231&i=d",index_col=0,parse_dates=True)
data.index.name = 'Date'
data.head()
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2022-01-03  4778.14  4796.64  4758.17  4796.56  2.241373e+09
# 2022-01-04  4804.51  4818.62  4774.27  4793.54  2.841121e+09
# 2022-01-05  4787.99  4797.70  4699.44  4700.58  2.810604e+09
# 2022-01-06  4693.39  4725.01  4671.26  4696.05  2.389339e+09
# 2022-01-07  4697.66  4707.95  4662.74  4677.03  2.414328e+09

# %%
_, axes = mpf.plot(
    data, type="line", style="yahoo", mav=(8, 20, 50), returnfig=True
)

axes[0].legend([None] * 5)
handles = axes[0].get_legend().legendHandles
axes[0].legend(handles=handles, labels=list(["Close Price", "MA 8", "MA 20", "MA 50"]))
