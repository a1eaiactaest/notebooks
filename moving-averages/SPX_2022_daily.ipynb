# %%
import mplfinance as mpf
import pandas as pd

# %%
#* Get data from Stooq 2022 daily chart
data = pd.read_csv("https://stooq.com/q/d/l/?s=^spx&d1=20220101&d2=20221231&i=d",index_col=0,parse_dates=True)
data.index.name = 'Date'
data.shape
data.head(3)
data.tail()
# Out:
#                Open     High      Low    Close        Volume
# Date
# 2022-09-27  3686.44  3717.53  3623.29  3647.29  2.543929e+09
# 2022-09-28  3651.94  3736.74  3640.61  3719.04  2.634240e+09
# 2022-09-29  3687.01  3687.01  3610.40  3640.47  2.604840e+09
# 2022-09-30  3633.48  3671.44  3584.13  3585.62  3.142946e+09
# 2022-10-03  3609.78  3698.35  3604.93  3678.43  2.062468e+09

# %%
_, axes = mpf.plot(
    data, type="line", style="yahoo", mav=(8, 20, 50), returnfig=True
)

axes[0].legend([None] * 5)
handles = axes[0].get_legend().legendHandles
axes[0].legend(handles=handles, labels=list(["Close Price", "MA 8", "MA 20", "MA 50"]))

# %%
mpf.plot(data,type='line',mav=(8,20,50),style="nightclouds")

# %%
mpf.plot(data,type='candle',mav=(8,20,50),style="yahoo")

# %%
mpf.plot(data, type="candle", mav=(8, 20, 50), style="nightclouds")
