# %%
import mplfinance as mpf
import pandas as pd

# %%
# * Get data from Stooq
data = pd.read_csv(
    "https://stooq.com/q/d/l/?s=btc.v&d1=20230101&d2=20231231&i=d",
    index_col=0,
    parse_dates=True,
)
data.index.name = "Date"
data.shape
data.head(3)
data.tail()
# Out:
#                 Open      High       Low     Close         Volume
# Date
# 2023-01-10  17202.83  17494.52  17128.96  17433.56  444493.292233
# 2023-01-11  17433.90  17593.31  17314.73  17555.01  434807.538423
# 2023-01-12  17555.98  19116.95  17550.68  18916.85  770225.257416
# 2023-01-13  18915.62  20001.60  18718.02  19851.05  878652.793439
# 2023-01-14  19854.70  21204.61  19736.21  20987.85  947812.181796

# %%
_, axes = mpf.plot(
    data, type="line", style="yahoo", mav=(8, 20, 50), returnfig=True
)

axes[0].legend([None] * 5)
handles = axes[0].get_legend().legendHandles
axes[0].legend(handles=handles, labels=list(["Close Price", "MA 8", "MA 20", "MA 50"]))

# %%
mpf.plot(data,type='line',mav=(8,20,50),style="nightclouds")

# %%
mpf.plot(data,type='candle',mav=(8,20,50),style="yahoo")

# %%
mpf.plot(data,type='candle',mav=(8,20,50),style="nightclouds")
