# %%
import mplfinance as mpf
import pandas as pd

# %%
# * Get data from Stooq
data = pd.read_csv(
    "https://stooq.com/q/d/l/?s=btc.v&d1=20230101&d2=20231231&i=d",
    index_col=0,
    parse_dates=True,
)
data.index.name = "Date"
data.shape
data.head(3)
data.tail()
# Out:
#                 Open      High       Low     Close         Volume
# Date
# 2023-02-24  23869.45  24132.29  22885.98  23119.67  619080.176447
# 2023-02-25  23118.98  23220.83  22800.76  23122.99  379176.241241
# 2023-02-26  23119.94  23675.60  23061.91  23478.90  407641.003593
# 2023-02-27  23478.68  23897.45  23118.92  23478.51  538677.302982
# 2023-02-28  23483.67  23600.47  23025.07  23161.79  548173.912332

# %%
_, axes = mpf.plot(
    data, type="line", style="yahoo", mav=(8, 20, 50), returnfig=True
)

axes[0].legend([None] * 5)
handles = axes[0].get_legend().legendHandles
axes[0].legend(handles=handles, labels=list(["Close Price", "MA 8", "MA 20", "MA 50"]))

# %%
mpf.plot(data,type='line',mav=(8,20,50),style="nightclouds")

# %%
mpf.plot(data,type='candle',mav=(8,20,50),style="yahoo")

# %%
mpf.plot(data,type='candle',mav=(8,20,50),style="nightclouds")
