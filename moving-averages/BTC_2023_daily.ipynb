# %%
import mplfinance as mpf
import pandas as pd

# %%
# * Get data from Stooq
data = pd.read_csv(
    "https://stooq.com/q/d/l/?s=btc.v&d1=20230101&d2=20231231&i=d",
    index_col=0,
    parse_dates=True,
)
data.index.name = "Date"
data.head()
# Out:
#                 Open      High       Low     Close         Volume
# Date
# 2023-01-01  16510.14  16619.17  16479.99  16594.55  203940.662269
# 2023-01-02  16594.57  16774.88  16543.40  16692.94  250512.922535
# 2023-01-03  16692.73  16771.28  16599.83  16670.72  343723.910613
# 2023-01-04  16670.69  16982.72  16647.86  16821.50  486505.981819
# 2023-01-05  16821.19  16872.23  16750.60  16832.67  340809.593505

# %%
_, axes = mpf.plot(
    data, type="line", style="yahoo", mav=(8, 20, 50), returnfig=True
)

axes[0].legend([None] * 5)
handles = axes[0].get_legend().legendHandles
axes[0].legend(handles=handles, labels=list(["Close Price", "MA 8", "MA 20", "MA 50"]))

# %%
mpf.plot(data,type='candle',mav=(8,20,50),style="yahoo")
