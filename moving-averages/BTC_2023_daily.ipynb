# %%
import mplfinance as mpf
import pandas as pd

# %%
# * Get data from Stooq
data = pd.read_csv(
    "https://stooq.com/q/d/l/?s=btc.v&d1=20230101&d2=20231231&i=d",
    index_col=0,
    parse_dates=True,
)
data.index.name = "Date"
data.shape
data.head(3)
data.tail()
# Out:
#                 Open      High       Low     Close        Volume
# Date
# 2023-02-16  24157.02  25190.38  23984.52  24013.83  8.458245e+05
# 2023-02-17  23997.87  25012.62  23347.09  24680.88  1.072481e+06
# 2023-02-18  24681.14  24876.21  24438.22  24631.37  4.636404e+05
# 2023-02-19  24630.97  25189.35  24266.79  24496.90  5.387614e+05
# 2023-02-20  24494.26  25098.26  23887.34  24732.55  6.953304e+05

# %%
_, axes = mpf.plot(
    data, type="line", style="yahoo", mav=(8, 20, 50), returnfig=True
)

axes[0].legend([None] * 5)
handles = axes[0].get_legend().legendHandles
axes[0].legend(handles=handles, labels=list(["Close Price", "MA 8", "MA 20", "MA 50"]))

# %%
mpf.plot(data,type='line',mav=(8,20,50),style="nightclouds")

# %%
mpf.plot(data,type='candle',mav=(8,20,50),style="yahoo")

# %%
mpf.plot(data,type='candle',mav=(8,20,50),style="nightclouds")
